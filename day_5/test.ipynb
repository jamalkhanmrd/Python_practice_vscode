# %% [markdown]
# **code ko seperate karnay ka liya ipynb use hoti hain**

# %% [markdown]
# # subeject of this python script:**
# # Authored by: Jamal khan
# # where to contact: github profile link "OR" email (gmail) google colab
#
# **

# %%
#code 1
print("ammar")
3+4
# Out:
# ammar
# 7

# %%
name_1="jamal"
name_1
# Out:
# 'jamal'

# %% [markdown]
# **is cell ko input function ka liya use kartay hain**

# %%
name=input("What is your name :")

# %% [markdown]
# **is function lo print kar nay ka liya use kartay hain
# **

# %%
#code 3
print("name",name)
# Out:
# name jama;l

# %% [markdown]
# 1. pandas-
# 2. numpy
# 3. matplotlib
# 4. seaborn
# 5. plotly
# 6. scipystats or scipy
# 7. scikit-learn
# 8. streamlit

# %%
#pip install numpy

# %%
#pip install pandas numpy seaborn matplotlib plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px

# %%
pd.read_excel()
